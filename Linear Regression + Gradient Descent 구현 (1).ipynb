# %% [markdown]
# # Training Data Set

# %%
x_data = [1, 2, 3]
y_data = [2, 4, 6]

# %% [markdown]
# # Hypotehsis -> 기울기 값

# %%
w = 1.0

# %% [markdown]
# # Hypotehsis -> Simplified Linear regression
